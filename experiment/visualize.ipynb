# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
route1 = np.loadtxt('route_001.csv', delimiter=',')
instruction1 = np.loadtxt('instructions_001.csv', delimiter=',')

# %%
inits1 = np.load('initial_new/init_0192.npz')
inits2 = np.load('initial_new/init_0193.npz')

# %%
rinits1 = np.array((inits1['y'][:-1], inits1['x'][:-1])).T
rinits2 = np.array((inits2['y'][:-1], inits2['x'][:-1])).T

# %%
rinits1.shape, rinits2.shape
# Out:
# ((1999, 2), (1999, 2))

# %%
plt.figure(figsize=[12,8])
plt.scatter(*route1.T, s=1, color='b')
plt.scatter(*rinits2.T, s=1, color='r')
#plt.scatter(*instruction1.T, s=1, color='r')
plt.show()

# %%
route1.shape
# Out:
# (2000, 2)

# %%
route1.shape, instruction1.shape
# Out:
# ((2000, 2), (500, 2))

# %%
points = np.loadtxt('instructions.csv', delimiter=",")

# %%
plt.figure(figsize=[12, 8])
plt.scatter(*points.T, s=1)
plt.show()

# %%
points.shape[0] / (600 * 400)
# Out:
# 0.008333333333333333

# %%
points.max(axis=0)
# Out:
# array([598., 399.])

# %%
points.max(axis=1)
# Out:
# array([  0., 300., 150., ..., 421., 399., 571.])

# %%
plt.figure(figsize=[12, 8])
plt.scatter(*points.T, s=1)
plt.show()
